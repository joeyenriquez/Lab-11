# %% [markdown]
# # Lab 11: Understanding the data.
#
# Last 2 classes we have been working on understanding data. In this lab you will apply that.
#
#
# **Context**
# The goal of this lab is to understand a large dataset of 27901 rows and 18 columns Perform Exploratory Data Analysis (EDA) on the data. Look at how the data effects the end result **depression** (yes/no)
#
# - Load and get a basic understanding of the dataset
# - Clean up the data
#     - examples:
#         - check and fix any missing data
#         - use both Hot and integer encoding
#         - convert any numeric data from strings to ints
# - Perform Exploratory Data Analysis (EDA)
#     - I will leave it to you to understand and explore this.
#         - Histplot
#         - Countplot
#         - Corelation
#         - Heatmaps
#         - boxplots
#         - have fun
#
# Make sure to communicate to me along the way. I want your to tell me what your assumptions are what your learning about the data and what you learned with EDA.  There are 18 data points for each student I expect an perform EDA on most of those points like what we did in class with MPG. (remember how we did a sns.pairplot(df[[ "cylinders", "mpg","model_year"]]) and sns.pairplot(df[["mpg", "horsepower", "weight", "displacement"]]) and others. )
#
# remember to have fun with this
#
# ----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# From: https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset/data
#
#
# Field Descriptions
#
# **id** - A unique identifier assigned to each student record in the dataset.
#
# **Gender** - The gender of the student (e.g., Male, Female, Other). This helps in analyzing gender-specific trends in mental health.
#
# **Age** - The age of the student in years.
#
# **City** - The city or region where the student resides, providing geographical context for the analysis.
#
# **Profession** - The field of work or study of the student, which may offer insights into occupational or academic stress factors.
#
# **Academic Pressure** - A measure indicating the level of pressure the student faces in academic settings. This could include stress from exams, assignments, and overall academic expectations.
#
# **Work Pressure** - A measure of the pressure related to work or job responsibilities, relevant for students who are employed alongside their studies.
#
# **CGPA** - The cumulative grade point average of the student, reflecting overall academic performance.
#
# **Study Satisfaction** - An indicator of how satisfied the student is with their studies, which can correlate with mental well-being.
#
# **Job Satisfaction** - A measure of the student’s satisfaction with their job or work environment, if applicable.
#
# **Sleep Duration** - The average number of hours the student sleeps per day, which is an important factor in mental health.
#
# **Dietary Habits** - An assessment of the student’s eating patterns and nutritional habits, potentially impacting overall health and mood.
#
# **Degree** - The academic degree or program that the student is pursuing.
#
# **Have you ever had suicidal thoughts ?** - A binary indicator (Yes/No) that reflects whether the student has ever experienced suicidal ideation.
#
# **Work/Study Hours** - The average number of hours per day the student dedicates to work or study, which can influence stress levels.
#
# **Financial Stress** - A measure of the stress experienced due to financial concerns, which may affect mental health.
#
# **Family History of Mental Illness** - Indicates whether there is a family history of mental illness (Yes/No), which can be a significant factor in mental health predispositions.
#
# **Depression** - The target variable that indicates whether the student is experiencing depression (Yes/No).

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# *Provided for reference only*
# ``` python
# import kagglehub
# import shutil
#
# # Download latest version
# path = kagglehub.dataset_download("adilshamim8/student-depression-dataset")
#
# #move the dowload to the current directory
# shutil.move(path, "./Lab_11_dataset")
# ````

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# loading the dataset
df = pd.read_csv("./Lab_11_dataset/student_depression_dataset.csv")
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import LabelEncoder

# %%
file_path = "./Lab_11_dataset/student-depression-dataset.csv"

# %%
# Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import LabelEncoder

# Step 1: Load and Understand the Dataset
# Check files in the current directory to locate the dataset
print("Files in current directory:")
print(os.listdir("."))

# Load the dataset (update file path based on actual location)
file_path = "./Lab_11_dataset/student-depression-dataset.csv"  # Replace with correct path
df = pd.read_csv(file_path)

# Basic understanding
print("\nDataset Info:")
print(df.info())
print("\nFirst 5 Rows:")
print(df.head())
print("\nMissing Values:")
print(df.isnull().sum())
print("\nUnique Values per Column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# Step 2: Clean the Data
# 2.1 Handle missing values
for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        df[column].fillna(df[column].median(), inplace=True)
    else:
        df[column].fillna(df[column].mode()[0], inplace=True)

# 2.2 Convert string numerical data to appropriate types
numerical_columns = ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 
                     'Job Satisfaction', 'Sleep Duration', 'Work/Study Hours', 'Financial Stress']
for col in numerical_columns:
    if col in df.columns and df[col].dtype == 'object':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric, NaN for invalid
        df[col].fillna(df[col].median(), inplace=True)  # Fill any new NaNs

# 2.3 Encoding categorical variables
# Integer encoding for binary/ordinal columns
le = LabelEncoder()
binary_columns = ['Have you ever had suicidal thoughts ?', 'Family History of Mental Illness', 'Depression']
for col in binary_columns:
    if col in df.columns:
        df[col] = le.fit_transform(df[col])

# One-hot encoding for multi-category columns
multi_category_columns = ['Gender', 'City', 'Profession', 'Dietary Habits', 'Degree']
df_encoded = pd.get_dummies(df, columns=[col for col in multi_category_columns if col in df.columns], drop_first=True)

# Step 3: Exploratory Data Analysis (EDA)
# 3.1 Univariate Analysis
# Histograms for numerical features
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_columns, 1):
    if col in df.columns:
        plt.subplot(3, 3, i)
        sns.histplot(df[col], kde=True)
        plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# Countplots for categorical features
categorical_columns = ['Gender', 'City', 'Profession', 'Dietary Habits', 'Degree', 
                      'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness', 'Depression']
plt.figure(figsize=(15, 10))
for i, col in enumerate(categorical_columns, 1):
    if col in df.columns:
        plt.subplot(3, 3, i)
        sns.countplot(x=col, data=df)
        plt.title(f'Count of {col}')
        plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3.2 Bivariate Analysis
# Boxplots: Numerical features vs. Depression
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_columns, 1):
    if col in df.columns:
        plt.subplot(3, 3, i)
        sns.boxplot(x='Depression', y=col, data=df)
        plt.title(f'{col} vs. Depression')
plt.tight_layout()
plt.show()

# Countplots: Categorical features vs. Depression
plt.figure(figsize=(15, 10))
for i, col in enumerate(categorical_columns[:-1], 1):  # Exclude Depression itself
    if col in df.columns:
        plt.subplot(3, 3, i)
        sns.countplot(x=col, hue='Depression', data=df)
        plt.title(f'{col} vs. Depression')
        plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3.3 Multivariate Analysis
# Correlation heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = df[numerical_columns + binary_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# Pairplot for selected numerical features
selected_features = ['Age', 'Academic Pressure', 'Sleep Duration', 'Financial Stress', 'Depression']
if all(col in df.columns for col in selected_features):
    sns.pairplot(df[selected_features], hue='Depression', diag_kind='kde')
    plt.show()

# Step 4: Communicate Findings
print("\nEDA Findings:")
print("- Missing values were handled by imputing medians for numerical and modes for categorical columns.")
print("- Numerical columns were checked for string-to-numeric conversion.")
print("- Binary columns (e.g., Depression, Suicidal Thoughts) were integer-encoded; multi-category columns (e.g., Gender, City) were one-hot encoded.")
print("- Histograms show distributions of numerical features (e.g., Age, CGPA).")
print("- Countplots reveal category frequencies (e.g., Gender, Profession).")
print("- Boxplots and countplots indicate relationships between features and Depression (e.g., higher Academic Pressure may correlate with Depression).")
print("- Correlation heatmap highlights relationships (e.g., Financial Stress and Depression may be correlated).")
print("- Pairplot shows pairwise relationships among key numerical features, colored by Depression.")
# Out:
# Files in current directory:
# ['IMG_9266.HEIC', '2 wishbone new.SLDPRT', 'Gearbox Speed Reducer.pdf', '03-Green Sand Casting.pdf', 'IMG_0028.jpg', 'Mos.Versions.3.4.1.dmg', 'Discord.dmg', 'IMG_9231.HEIC', 'Gear_Excel_Initialization+Sheet.pdf group 5 .pdf', 'ETE4990 hw3p2.pdf', 'IMG_7805.HEIC', 'OperaSetup.zip', 'etm2201 final.pdf', 'Pinion 2.xlsx', 'IMG_6C27BD72B274-1.jpeg', 'IME4020.pdf', 'ETE4990 Hw4.pdf', '1:3.pdf', 'IMG_7813.HEIC', 'Autodesk_AutoCAD_2026_macOS.dmg', '9780133951929, Chapter 14, Problem 43P.png', 'Lecture 4 -.ipynb', 'etm3351hw1.pdf', 'etm4990 hw 7 update.pdf', 'IMG_2113 5.MOV', 'ETE 4141L Laboratory #2 (2).pdf', 'IMG_7002.HEIC', 'Ete hw5 copy 2.pdf', 'Lecture 17 - Error Logs.ipynb', 'ETE 3211 Lab 10.pdf', 'Untitled_document.docx', 'Project_1.ipynb', 'Visual Studio Code.app', 'IMG_2113 4.MOV', 'IMG_7429.HEIC', 'Untitled document (5).pdf', 'ETE4990HW7.pdf', 'initials for cnc.txt', 'Steel_Spring2019.xlsx', 'summary.json', 'Ete2011hw#5.pdf', 'cpp-sap-academic-plan-08092023.pdf', 'IMG_8772.HEIC', 'Lab12_nazari.pdf', 'MCQ_ch03 (2).docx', 'ETE4990 Lab4.pdf', 'IMG_0029.jpg', '9780133951929, Chapter 12, Problem 214P.png', 'panelvfront view.jpg', '9780133951929, Chapter 12, Problem 85P.png', 'IMG_8302.HEIC', 'IMG_1309.JPG', 'archived_log.log', 'Documents-20250428T010410Z-001.zip', 'IMG_8705.HEIC', 'Main Code (3).ipynb', 'etehw9.pdf', '15 a) Determine the thermal voltages for a diode at 2.pdf', 'VSCode-darwin-universal (1).zip', 'ETE4990 hw3p1.pdf', 'cstcadnavigator_mac64.dmg', 'IMG_6961.HEIC', 'lab5.heic', 'IMG_6998.HEIC', 'midtermp3.HEIC', 'Notes and study guides 2010 Sept 21.doc', 'Lab3.pdf', 'shaft 3 - Sheet1 (1).pdf', 'HW 6.zip', 'IMG_9155.HEIC', 'Lab2 -  Refactoring.ipynb', 'midterm3p3.HEIC', 'message (1).txt', 'etm3351hw2.pdf', 'IMG_8601.HEIC', 'Health Afflictions.ipynb', 'IMG_7798.HEIC', 'Untitled document (9).pdf', 'IMG_7425.HEIC', 'IMG_7625.jpg', '3:3.pdf', 'Lab 1a- Markdown.ipynb', 'Given the following circuit (partial answer phase H(j100000) = -14.04 degrees).pdf', 'strength spring 2023.xlsx', 'ETE4141 Lab2.pdf', 'etehw8.pdf', '15 a) Determine the thermal voltages for a diode at 3.pdf', 'Project_1 (1).ipynb', '1 wishbone new.SLDPRT', 'Gearbox Speed Reducer (2) (2).pdf', '9780133951929, Chapter 12, Problem 89P.png', 'ETE4990 lab7.pdf', 'IMG_1308.JPG', '09-Welding (2).pdf', '9780133951929, Chapter 13, Problem 4P.png', 'midterm1p2.HEIC', 'Transact _ Receipt.pdf', '9780133951929, Chapter 12, Problem 218P.png', 'etm_3151_lab_assign_2 (1).pdf', 'Note_Nov_22_2023.pdf', 'differential-gear-24.snapshot.1.zip', 'midterm1p3.HEIC', 'Input_shaft_1 (1).tif', 'Gearbox Speed Reducer (1).pdf', 'ETM2201 HW.pdf', '9780133951929, Chapter 14, Problem 4P.png', 'IMG_7432.HEIC', 'ItemData (1).json', 'ScienceDirect_articles_21May2024_04-55-28.802.zip', 'IMG_8682.HEIC', '4_Dual_axis_motor_journal.pdf', 'Laboratory7_Procedure.pdf', '1) a) Use Load line method to find V_D, I_D and V_R..pdf', 'cpp fasfa sap form.pdf', 'Main Code (1).ipynb', 'ETE4990 HW2.pdf', 'Determine the range of the stiffness of the engine mounting system in order to isolate the engine excitation if the engine firing frequency is 20~80 Hz. The weight of the engine is 300 lb.pdf', 'Lab 4 _ Part 3.docx', 'Lab 3 Functions (1).ipynb', '416781958_808139681120862_6405638507100480880_n.jpg', '_YourName_Lab 11.ipynb', 'IMG_3280.pdf', 'IMG_2113 3.MOV', 'IMG_7218.HEIC', '.DS_Store', 'HW 3.zip', 'etmfinal .pdf', 'eclipse', 'Untitled document (8).pdf', '9780133951929, Chapter 16, Problem 6P.png', 'Yunus A. Cengel, Robert H. Turner, John M. Cimbala - Fundamentals of Thermal-Fluid Sciences-Heat Transfer Section (1).pdf', 'ETE.4990HW6.py', 'IMG_7799.HEIC', 'ete3211q1.jpg', 'Pinion 2 - Sheet1 (1).pdf', 'ETE 3211.L LAB 8.pdf', 'hw10 4:12.pdf', 'midterm3p2.HEIC', 'IMG_2113 2.MOV', 'ETE3211 HW9.pdf', 'IMG_8600.HEIC', 'IMG_6999.HEIC', 'CPP SAP UGRD Max Time Frame Academic Plan.pdf', 'HW6 Nazari.pdf', 'paper_sp24_draft (1).doc', 'ETE 3211 Lab 6 (2).pdf', 'logioptionsplus_installer.zip', 'ETM 2201 midterm 2.pdf', 'I ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 16
#      14 # Load the dataset (update file path based on actual location)
#      15 file_path = "./Lab_11_dataset/student-depression-dataset.csv"  # Replace with correct path
# ---> 16 df = pd.read_csv(file_path)
#      18 # Basic understanding
#      19 print("\nDataset Info:")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Lab_11_dataset/student-depression-dataset.csv'

# %%
import os
print("Current working directory:", os.getcwd())
print("Files in current directory:", os.listdir("."))
# Out:
# Current working directory: /Users/joeyenriquez/Downloads
# Files in current directory: ['IMG_9266.HEIC', '2 wishbone new.SLDPRT', 'Gearbox Speed Reducer.pdf', '03-Green Sand Casting.pdf', 'IMG_0028.jpg', 'Mos.Versions.3.4.1.dmg', 'Discord.dmg', 'IMG_9231.HEIC', 'Gear_Excel_Initialization+Sheet.pdf group 5 .pdf', 'ETE4990 hw3p2.pdf', 'IMG_7805.HEIC', 'OperaSetup.zip', 'etm2201 final.pdf', 'Pinion 2.xlsx', 'IMG_6C27BD72B274-1.jpeg', 'IME4020.pdf', 'ETE4990 Hw4.pdf', '1:3.pdf', 'IMG_7813.HEIC', 'Autodesk_AutoCAD_2026_macOS.dmg', '9780133951929, Chapter 14, Problem 43P.png', 'Lecture 4 -.ipynb', 'etm3351hw1.pdf', 'etm4990 hw 7 update.pdf', 'IMG_2113 5.MOV', 'ETE 4141L Laboratory #2 (2).pdf', 'IMG_7002.HEIC', 'Ete hw5 copy 2.pdf', 'Lecture 17 - Error Logs.ipynb', 'ETE 3211 Lab 10.pdf', 'Untitled_document.docx', 'Project_1.ipynb', 'Visual Studio Code.app', 'IMG_2113 4.MOV', 'IMG_7429.HEIC', 'Untitled document (5).pdf', 'ETE4990HW7.pdf', 'initials for cnc.txt', 'Steel_Spring2019.xlsx', 'summary.json', 'Ete2011hw#5.pdf', 'cpp-sap-academic-plan-08092023.pdf', 'IMG_8772.HEIC', 'Lab12_nazari.pdf', 'MCQ_ch03 (2).docx', 'ETE4990 Lab4.pdf', 'IMG_0029.jpg', '9780133951929, Chapter 12, Problem 214P.png', 'panelvfront view.jpg', '9780133951929, Chapter 12, Problem 85P.png', 'IMG_8302.HEIC', 'IMG_1309.JPG', 'archived_log.log', 'Documents-20250428T010410Z-001.zip', 'IMG_8705.HEIC', 'Main Code (3).ipynb', 'etehw9.pdf', '15 a) Determine the thermal voltages for a diode at 2.pdf', 'VSCode-darwin-universal (1).zip', 'ETE4990 hw3p1.pdf', 'cstcadnavigator_mac64.dmg', 'IMG_6961.HEIC', 'lab5.heic', 'IMG_6998.HEIC', 'midtermp3.HEIC', 'Notes and study guides 2010 Sept 21.doc', 'Lab3.pdf', 'shaft 3 - Sheet1 (1).pdf', 'HW 6.zip', 'IMG_9155.HEIC', 'Lab2 -  Refactoring.ipynb', 'midterm3p3.HEIC', 'message (1).txt', 'etm3351hw2.pdf', 'IMG_8601.HEIC', 'Health Afflictions.ipynb', 'IMG_7798.HEIC', 'Untitled document (9).pdf', 'IMG_7425.HEIC', 'IMG_7625.jpg', '3:3.pdf', 'Lab 1a- Markdown.ipynb', 'Given the following circuit (partial answer phase H(j100000) = -14.04 degrees).pdf', 'strength spring 2023.xlsx', 'ETE4141 Lab2.pdf', 'etehw8.pdf', '15 a) Determine the thermal voltages for a diode at 3.pdf', 'Project_1 (1).ipynb', '1 wishbone new.SLDPRT', 'Gearbox Speed Reducer (2) (2).pdf', '9780133951929, Chapter 12, Problem 89P.png', 'ETE4990 lab7.pdf', 'IMG_1308.JPG', '09-Welding (2).pdf', '9780133951929, Chapter 13, Problem 4P.png', 'midterm1p2.HEIC', 'Transact _ Receipt.pdf', '9780133951929, Chapter 12, Problem 218P.png', 'etm_3151_lab_assign_2 (1).pdf', 'Note_Nov_22_2023.pdf', 'differential-gear-24.snapshot.1.zip', 'midterm1p3.HEIC', 'Input_shaft_1 (1).tif', 'Gearbox Speed Reducer (1).pdf', 'ETM2201 HW.pdf', '9780133951929, Chapter 14, Problem 4P.png', 'IMG_7432.HEIC', 'ItemData (1).json', 'ScienceDirect_articles_21May2024_04-55-28.802.zip', 'IMG_8682.HEIC', '4_Dual_axis_motor_journal.pdf', 'Laboratory7_Procedure.pdf', '1) a) Use Load line method to find V_D, I_D and V_R..pdf', 'cpp fasfa sap form.pdf', 'Main Code (1).ipynb', 'ETE4990 HW2.pdf', 'Determine the range of the stiffness of the engine mounting system in order to isolate the engine excitation if the engine firing frequency is 20~80 Hz. The weight of the engine is 300 lb.pdf', 'Lab 4 _ Part 3.docx', 'Lab 3 Functions (1).ipynb', '416781958_808139681120862_6405638507100480880_n.jpg', '_YourName_Lab 11.ipynb', 'IMG_3280.pdf', 'IMG_2113 3.MOV', 'IMG_7218.HEIC', '.DS_Store', 'HW 3.zip', 'etmfinal .pdf', 'eclipse', 'Untitled document (8).pdf', '9780133951929, Chapter 16, Problem 6P.png', 'Yunus A. Cengel, Robert H. Turner, John M. Cimbala - Fundamentals of Thermal-Fluid Sciences-Heat Transfer Section (1).pdf', 'ETE.4990HW6.py', 'IMG_7799.HEIC', 'ete3211q1.jpg', 'Pinion 2 - Sheet1 (1).pdf', 'ETE 3211.L LAB 8.pdf', 'hw10 4:12.pdf', 'midterm3p2.HEIC', 'IMG_2113 2.MOV', 'ETE3211 HW9.pdf', 'IMG_8600.HEIC', 'IMG_6999.HEIC', 'CPP SAP UGRD Max Time Frame Academic Plan.pdf', 'HW6 Nazari.pdf', 'paper_sp24_draft (1).doc', 'ETE 3211 Lab 6 (2).pdf', 'logioptionsplus_installer.zip',  ...
